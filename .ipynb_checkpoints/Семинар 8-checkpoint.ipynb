# %% [markdown]
# *из 7ого семинара*

# %% [markdown]
# ![7.8.png](attachment:7.8.png)

# %% [markdown]
# $\chi^2 = \frac{\hat{\sigma}^2(n-1)}{\sigma_0^2} = \frac{\hat{9\sigma}^2}{\sigma_0^2} > \chi^2_{0.05, 9} = 16.92$
#
# Критерий: $\frac{\hat{\sigma}^2(n-1)}{\sigma_0^2} > 16.92 \to !H_0$
#
# $P(H_A|H_A) = P\left(\frac{9\hat{\sigma}^2}{\sigma_0^2} > 16.92|\sigma^2 = 2\sigma_0^2\right) = P\left(\frac{9\hat{\sigma}^2}{2\sigma_0^2} > \frac{16.92}{2}\right) = P(\chi^2>8.46)$

# %% [markdown]
# ![7.8.1.jpg](attachment:7.8.1.jpg)

# %% [markdown]
# $1 - \beta = 0.4885$

# %% [markdown]
# В задаче 9 надо искать критерий по другому, двусторонним образом, и при этом статистика должна распрелиться по 2 хвостам: $0.025$ и $0.975$

# %% [markdown]
# ![7.11.png](attachment:7.11.png)

# %% [markdown]
# $n =10$, $Z_{0.025} = 1.96$
#
# Какому уровню значимости соответствует $1.96$ в Стьюденте?

# %% [markdown]
# ![7.11.1.jpg](attachment:7.11.1.jpg)

# %% [markdown]
# $P(H_A|H_0) = 0.082$

# %% [markdown]
# при  $n=1000$ наше распределение Стьюдента асимптотически сводится к нормальному, $\alpha = 0.05$

# %% [markdown]
# *задачи из 8ого семинара*

# %% [markdown]
# ![8.1.png](attachment:8.1.png)

# %% [markdown]
# $H_0$: $p_A = 0.5$
#
# $H_1$: $p_A > 0.5$
#
# $\alpha = 0.01$, $\hat p_A = \frac{280}{500} = 0.56$
#
# Критерий: $Z > Z^{\text{критическое}} \to !H_0$
#
# $Z = \frac{\hat p_A - p_A}{\sqrt{\frac{p_A(1-p_a)}{n}}} = \frac{0.56 - 0.5}{\sqrt{\frac{0.5\cdot0.5}{500}}} = 2.68$
#
# $Z_{0.01} = 2.33 < 2.68 \to$ отвергаем $H_0$.
#
#
#
# в) $\text{p-value} = P(Z>2.68) = 1 - 0.9963 = 0.0037 = \alpha^{\text{фактическое}}$
#
# $\alpha^{\text{фактическое}}$ - минимальный уровень значимости, на котором $H_0$ отвергается. Если
# $\alpha > \alpha^{\text{фактическое}}$, то помним что на всяких бóльших $\alpha$ мы будем отвергать нулевую гипотезу.
#
# Абстрактно:
# пусть $\text{p-value} = 0.03$, тогда при $\alpha_1 = 0.01 \to H_0$; при $\alpha_2 = 0.05 \to !H_0$

# %% [markdown]
# ![8.2.jpg](attachment:8.2.jpg)

# %% [markdown]
# $\hat p = 0.26$
#
# $H_0$: $p = 0.2$
#
# $H_A$: $p>0.2$
#
# Статистика: $Z = \frac{0.26 - 0.2}{\sqrt{\frac{0.2\cdot0.8}{100}}} = 1.5$
#
# $Z_{0.05} = 1.645$
#
# $Z < Z_{0.05} \to$ мы не отвергаем нулевую гипотезу.
#
# $\text{p-value} = P(Z>1.5) = 1 - 0.9332 = 0.0668$

# %% [markdown]
# ![8.4.jpg](attachment:8.4.jpg)

# %% [markdown]
# $H_0$: $P(X = X_i) = 0.5^X$
#
# $H_A$: $P(X = X_i) \neq 0.5^X$
#
# $\chi^2 = \sum_{i=1}^k\frac{(Observed_i - Expected_i)^2}{Expected_i} = \sum_{i=1}^4\frac{(O_i - E_i)^2}{E_i} \sim^{H_0} X^1_{k-1}$, $k$ - число групп, на которые мы разбили наши наблюдения
#
# Просчитаем $E_i$:
#
# $E_1 = 0.5^1\cdot60 = 30$
#
# $E_2 = 0.5^2\cdot60 = 15$
#
# $E_3 = 0.5^3\cdot60 = 7.5$
#
# $E_4 = 60 - E_1 - E_2 - E_3 = 7.5$
#
# Расчётная статистика: $\chi^2 = \frac{(28 - 30)^2}{30} + \frac{(20 - 15)^2}{15} + \frac{(8 - 7.5)^2}{7.5} = \frac{(4 - 7.5)^2}{7.5} = 3.4(6)$
#
# Уровень значимости $\alpha = 0.05$
#
# $\chi^2_{\alpha, k-1} = \chi^2_{0.05, 3} = 7.815$
#
# чем меньше $\chi^2$, тем больше оно совпадает с ожидаемым
#
# $\chi^2 < \chi^2_{0.05, 3} \to $ не отвергается $H_0$

# %% [markdown]
# ![8.4.1.jpg](attachment:8.4.1.jpg)

# %% [markdown]
# $\text{p-value} = 0.326$
#
# б) $n = 255$, $P(p>0.55|H_0) = P\left(p>0.55|E_1 = 0.5^1\right) = P\left(Z > \frac{0.55 - 0.5}{\sqrt{\frac{0.5\cdot0.5}{225}}}\right) = P(Z > 1.5) = 0.0668$

# %% [markdown]
# \\\ дз 8.10,8.11,8.12
