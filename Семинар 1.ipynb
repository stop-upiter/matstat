# %% [markdown]
# ## Гуден морген, амин.
# преподка, ребенок (предпол. девочка возраста Милы), кажется есть кошка, пережёвывает. (тетя Катя?)

# %% [markdown]
# ### Reminder
# $E(X)$ техническое понятие. $E(X) = \sum_{i=1}^n x_ip_i$.
#
# Пусть есть лотерея, 1ая: $100$ долларов или $0$ долларов равновероятно; 2ая: 50 долларов в любом случае. Матожидания у них одинаковы. $E_1(X) = 50 = E_2(X)$ Однако это значение не даст нам полной картины.
#
# Дисперсия - некоторая мера разброса. Хотим, чтобы она была как можно меньше. $D(X) = E(X^2) - E^2(X)$
#
# Свойства матожидания:
#
# 1. $E(const) = const$
#
# 2. $E(c\cdot X) = cE(X)$
#
# 3. $
# E(X+Y) = E(X)+E(Y)
# $
#
# 4. $
# E(XY)=E(X)E(Y)
# $, если они независимые!!!
#
# Свойства дисперсии:
#
# 1. $
# D(const) = 0
# $
#
# 2. $
# D(c\cdot X) = c^2D(X)
# $
#
# 3. $
# D(X+Y) = D(X)+D(Y)+2cov(X,Y)
# $
#
# доп:
# $D(X-Y) = D(X)+(-1)^2D(Y) - 2cov(X,Y)$

# %% [markdown]
# ![1.1.png](attachment:1.1.png)

# %% [markdown]
# #### Условие независимости для дискретного случая:
#
# $
# P(X=x_i;Y=y_j) = P(X=x_i)P(Y=y_i)
# $
#
# Пусть $x_i = 0$, $y_j=0$, тогда $P(0;0) = 0.2$,
# при этом $P(X=0) = 0.4$, $P(Y=0) = 0.4 \to P(X=0)P(Y=0) = 0.16 \neq 0.2 \to$ зависимые величины!

# %% [markdown]
# $
# E(X) =X_0\cdot\sum p_{X_0} + X_1\cdot\sum p_{X_1} = 0\cdot(0.1+0.2+0.1) + 1\cdot(0.2\cdot3) = 0.6
# $

# %% [markdown]
# $E(Y) = Y_0\cdot\sum p_{Y_0} + Y_1\cdot\sum p_{Y_1} + Y_2\cdot\sum p_{Y_2} = -1\cdot0.3 + 0\cdot0.4 + 1\cdot0.3 = 0$

# %% [markdown]
# ![1.1.2.png](attachment:1.1.2.png)

# %% [markdown]
# $E(XY) = -0.2+0+0.2 = 0$

# %% [markdown]
# Ковариация:
#
# $cov(X,Y) = E(XY) - E(X)E(Y) = 0 - 0.6\cdot 0 = 0$ и при этом величины не являются независимыми!!! и это ок!!!

# %% [markdown]
# $E(X^2 - 3X + 7) = E(X^2)-3E(X) + 7$
#
# $E(X^2) = 0\cdot p_0 + 1\cdot p_1 = E(X) = 0.6$
#
# $
# E(X^2 - 3X + 7) = 0.6 - 1.8 + 7 = 5.8
# $

# %% [markdown]
# ![1.2.png](attachment:1.2.png)

# %% [markdown]
# (1) Условие независимости:
#
# $
# P(X=x_i;Y=y_j) = P(X=x_i)P(Y=y_i)
# $
#
# $P(X = 0; Y = 1) = 0.2$, $P(X=0)=0.8$ $\to$ $P(Y = 1) =0.2 + a = \frac{P(X=0)}{P(X = 0;Y = 1)} = 0.25$ $\to$ $a = 0.05$
#
# Ищем $b$: $b = 1 - 0.2-0.2-0.4-0.05-0.05 = 0.1$

# %% [markdown]
# (2) $E(XY-2)$ и $D(XY-2)$
#
# Так как величины независимые, то
#
# $E(XY-2) = E(XY)-2 = E(X)\cdot E(Y) - 2 = 0.2 \cdot (0.25+1) - 2 = 0.25 - 2 = -1.75$
#
# $D(XY - 2) = D(XY) = E((XY)^2) - E^2(XY)$

# %% [markdown]
# ![1.2.1.png](attachment:1.2.1.png)

# %% [markdown]
# $E(XY) = 0.05 + 0.2 = 0.25$ $\to$ $E^2(XY) = 0.0625$
#
# $E((XY)^2) = 0.05 + 0.4 = 0.45$
#
# $D(XY) = 0.45 - 0.0625 = 0.3875$

# %% [markdown]
# (3) $cov(X, X+Y)$
#
# $cov(X, X+Y) = cov(X,X) + cov(X,Y) = D(X) + cov(X,Y) = D(X) = E(X^2) - E^2(X) =[\text{в силу реализации}]= E(X) - E^2(X) = 0.2 - 0.04 = 0.16$

# %% [markdown]
# ![1.4.png](attachment:1.4.png)

# %% [markdown]
# Проверяем по условию вероятности:
#
# $P(X=2;Y=3) = 0.5$, $P(X=2) = 0.5$, $P(Y=3) = 0.5$. Так как $0.5 \neq 0.5\cdot 0.5$, то величины зависимы.

# %% [markdown]
# ![1.6.png](attachment:1.6.png)

# %% [markdown]
# а) $\sum p_i(X) = 1$ $\to$ $3a+b+0.2 = 1$; $3a+b = 0.8$ $\to$ очевидно $b \in [0;0.8]$; при $b_{min} = 0$ $3a = 0.8$; $a = \frac{0.8}3 = \frac{4}{15}$, при $b_{max} = 0.8$ $a=0$ $\to$ $a \in [0;\frac{4}{15}]$
#
# б) $a = 0.1$ $\to$ $b = 0.8 - 0.3 = 0.5$
#
# $E(X + XY) = E(X) + E(XY) = [\text{так как величины независимы}] = E(X) + E(X)E(Y) = [\text{так как по условию одинаковые распределения}] = $
#
# $E(X) + E^2(X) = [E(X) = -0.1 + 0.5 + 0.4 = 0.8] = 0.8 + 0.64 = 1.44$
#
# $cov(X-7,X+Y) = cov(X, X+Y) = cov(X,X) + cov(X,Y) = [\text{в силу независимости величин ковариация нулевая}] = D(X) = E(X^2) - E^2(X) = (0.1+0.5+0.8) - 0.64 = 1.4 - 0.64 = 0.76$

# %% [markdown]
# ![1.7.png](attachment:1.7.png)

# %% [markdown]
# a) $E(2X+Y-4) = 2E(X) + E(Y) - 4 = 2 + 2 - 4 = 0$
#
# б) $D(2X) = 4D(X) = 12$
#
# в) $D(2X - 3Y + 1) = 4D(X) + 9D(Y) -12cov(X,Y) = 12 + 36 + 12 = 60$
#
# //это на следующий семинар.
#
# г) $corr(X,Y) = \frac{cov(X,Y)}{\cdot}$
