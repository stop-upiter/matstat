# %% [markdown]
# Дз: От нас ждут содержательный вывод. Когда вы строите два доверительных интервала, сравните их потом.
# > Задавайте мне вопросы (по дз), я готова отвечать.

# %% [markdown]
# ### Семинар 5

# %% [markdown]
# Вспомним, что была ошибочка. когда $\sigma^2$ неизвестна и в качестве оценки используется $\hat{\sigma}^2$ для доверительного интервала для $\mu$ при $n$, у нас распределение $t_{n-1}$ и формула $\mu \pm \frac{\hat{\sigma}}{\sqrt n}$

# %% [markdown]
# Вернёмся к задаче из сема 4:

# %% [markdown]
# ![4.9.png](attachment:4.9.png)

# %% [markdown]
# 1) $n=14$
#
# У старца Феодосия интервал: $\bar{X} \pm Z_{0.025}\frac{\sigma}{\sqrt n}$, $error F = Z_{0.025}\frac{\sigma}{\sqrt n}$
#
# У Тимофеюшки: $\bar{X} \pm t_{0.025, 13}\frac{\hat{\sigma}}{\sqrt {n}}$, $error T = t_{0.025, 13}\frac{\hat{\sigma}}{\sqrt {n}}$
#
# $P(errorT > errorF) = $

# %% [markdown]
# $=P\left(t_{0.025, 13}\frac{\hat{\sigma}}{\sqrt {n}} > Z_{0.025}\frac{\sigma}{\sqrt n}\right) = P\left(t_{0.025, 13}\hat{\sigma} > Z_{0.025}\sigma\right)$
#
# Приводим к хи-квадрату
#
# $ P\left(t_{0.025, 13}\frac{\hat{\sigma}\sqrt{n-1}}{\sigma} > Z_{0.025}\frac{\sigma\sqrt{n-1}}{\sigma}\right) = P\left(\frac{\hat{\sigma}\sqrt{n-1}}{\sigma} > Z_{0.025}\frac{\sqrt{n-1}}{t_{0.025, 13}}\right) = P\left(\sqrt{\chi_{n-1}^2}>Z_{0.025}\frac{\sqrt{n-1}}{t_{0.025, 13}}\right) = P\left(\chi_{n-1}>Z_{0.025}^2\frac{n-1}{t_{0.025, 13}^2}\right) = $
#
# $P(\chi_{13}>10.7) \in (0.5;0.7)$

# %% [markdown]
# ![1.png](attachment:1.png)

# %% [markdown]
# a) $P(-1 < X < 1) = 2Z_{1} \approx 2\cdot 0.34 = 0.68$
#
# b) $P(Y^2 + Z^2 > 5.99) = P(\chi^2_2 > 5.99) = 0.05$
#
# Есть хитрость. Если есть последовательность стандартным нормальных величин $X_1, ..., X_k \sim N$, то $X_1^2, ..., X_k^2 \sim \chi^2$
#
# c) $P\left(|\frac{X}{\sqrt{Y^2 + Z^2}}| > 3\right) = $ Саша говорит что это стьюдент
#
# Вспоминаем вид Стьюдента: $t = \frac{X_0}{\sqrt{\frac 1 k \sum_{j=1}^k X^2_j}}$, числитель $\sim N(0;1)$, знаменатель $\sim \chi^2$
#
# $ = P\left(|t|>3\sqrt 2\right) = 2P\left(t > 3\sqrt 2\right) \approx 2P\left(t > 4.2\right) \approx 0.1$

# %% [markdown]
# ![5.2.png](attachment:5.2.png)

# %% [markdown]
# $X \sim N(\mu, 5^2)$, $n = 16$, наш интервальчик: $\bar{X} \pm Z_{\frac{\alpha}{2}}\frac{\sigma}{\sqrt n}$
#
# a) $P\left(|\bar{X} - \mu| > 2\right) = P\left(|Z_{\frac{\alpha}{2}}\frac{\sigma}{\sqrt n}|>2\right) = P\left(|Z_{\frac{\alpha}{2}}| >\frac{2\sqrt n}{\sigma}\right) = P\left(|Z_{\frac{\alpha}{2}}| > 1.6\right) = (1 - Z_{0.6})\cdot 2 = (1 - 0.4452)\cdot 2 = 0.1096$
#
# b) $P\left(|\bar{X}-\mu|>1\right) \leq 0.0455$
#
# $1 - P\left(|\bar{X}-\mu|>1\right) \geq 1 - 0.0455$
#
# $P\left(|\bar{X} - \mu|\leq 1\right) \geq 0.9545 $
#
# $Z_{\frac{\alpha}2}\frac{\sigma}{\sqrt n} \leq 1$
#
# $Z_{\frac{\alpha}2} = 1.96$
#
# $\frac{1.96^2 \cdot 5}{\sqrt n} \leq 1$
#
# $\sqrt n \geq 1.965$, $n \geq 71.4025$, $n$ - целое, $n_{min} = 72$

# %% [markdown]
# ![5.3.png](attachment:5.3.png)

# %% [markdown]
# a) $p = \frac m n$, $m$ - успехи, $n$ - попытки. $p \in [0;1]$
#
# $D = \frac{p(1 - p)}n \in \left[0; \frac{0.25}{144}\right]$
#
# По идее это биноминальное распределение. Но здесь слишком большое $n$, поэтому аппроксимируем к нормальному распределению.
#
# b) $P(error \leq 0.3) = 0.9$, $n$ - ?
#
# Будем считать что $p(1-p) = 0.25$, так ещё берём максимальную дисперсию, так как мы не знаем $p$
#
# $Z_{\frac{\alpha}{2}}\sqrt{\frac{p(1-p)}{n}}\leq 0.3$
#
# $P = 0.9$, в каждом полуинтервале $0.45$, значит ищем $P(Z) = 0.45$, берем $Z = 1.645$
#
# $1.645\cdot\sqrt{0.25} \leq 0.3\sqrt n$
#
# $\frac{1.645^2\cdot 0.25}{0.3^2} \leq n$
#
# $n \geq 751, 67$, $n_{min} = 752$
#
# c) $\hat{p} = \frac{36}{144} = 0.25$, $Z_{\frac{\alpha}{2}} = 1.96$
#
# $\hat{p} - Z_{\frac{\alpha}{2}}\sqrt{\frac{\hat{p}(1 - \hat p)}{n}} < p < \hat{p} + Z_{\frac{\alpha}{2}}\sqrt{\frac{\hat{p}(1 - \hat p)}{n}} \to $
#
# $p \in \left( 0.25 \pm 1.96\cdot \sqrt{\frac{0.25\cdot0.75}{144}}\right) = (0.25 - 0.07; 0.25+0.07) = (0.18;0.32)$

# %% [markdown]
# ![5.4.png](attachment:5.4.png)

# %% [markdown]
# a) По таблице хи-квадрата $P(\chi^2_3 > 4.642) = 0.2$
#
# b) $P(\chi^2_3>1.424) = 0.7$, $P(\chi^2_3>7.815) = 0.05$, $P(1.424<\chi^2_3<7.815) = 0.7 - 0.05 = 0.65$
#
# c) $P(|t_7| < 1.895) = 1 - P(|t_7| > 1.895) = 0.9$
#
# d) $P(-0.402<t_7<0.130) = P\left(Y\in(0;0.13)\right) + P\left(Y\in(0;0.402)\right)$
#
# $P\left(t_7\in(0;0.13)\right) = \frac12\left(1 - P(|t_7|<0.13)\right)$ //дз досчитать

# %% [markdown]
# ![5.5.png](attachment:5.5.png)

# %% [markdown]
# //дз
